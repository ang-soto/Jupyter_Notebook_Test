# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# Objetivos:
# * Conocer algunos lenguajes usados en la ciencia de datos
# * Conocer algunas de las bibliotecas usadas en ciencia de datos
# * Conocer algunas herramientas usadas en ciencias de datos

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
# 1. PYTHON
# 2. R
# 3. JULIA
# 4. SCALA

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
# 1. Python:
#    1. scikit-learn
#    2. TensorFlow
# 2. R
#    1. caret
#    2. randomForest

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# |----------------------------------|
# | GitHub                          |
# | Jupyter Notebook                |
# | R                               |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %% [markdown]
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# Esto convertirá 200 minutos a horas dividiendo por 60

# %%
Minutos = 200
Horas = Minutos // 60
Resto_minutos = Minutos % 60
print(f"{Horas} horas y {Resto_minutos} minutos")
# Out:
# 3 horas y 20 minutos

# %% [markdown]
# ## Autor:
# Angel Soto
